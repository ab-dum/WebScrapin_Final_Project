# %% [markdown]
# # WEB SCRAPING FOR EMLAKJET.COM
# In this project, it's aimed to scrape the property pricing data from emlakjet.com for Antalya/Turkey and to make EDA on data

# %%
# importing packages
import pandas as pd
from bs4 import BeautifulSoup
import requests
import cloudscraper
import scrapethat

# %%
# creating helper functionss to read the links and extract the text
def read_html(link):
    response = requests.get(link)
    return(BeautifulSoup(response.text, 'html'))

def get_texts(link_nodes):
    return([x.text for x in link_nodes])

# %%
# creating function for filtering the informations we need according the their HTML tag 
# using try and except for error handling of the function
def get_one_ship(link):
    try:
        t = read_html(link)

        # extracting the ad key number 
        elements_ad_number = t.select('._1bVOdb:nth-child(1)') # SelectorGadget was used for finding HTML tag
        key_ad_number = get_texts(elements_ad_number)[0] if elements_ad_number else None

        # extracting the ad value number according to HTML tag
        ad_number_value_elements = t.select('._1bVOdb:nth-child(1) + ._1bVOdb') # SelectorGadget was used for finding HTML tag
        ad_number_value = get_texts(ad_number_value_elements)[0] if ad_number_value_elements else None

        # extracting the price according the HTML tag(since the price is not in the ad key and ad value elements)
        price_elements = t.select('._2TxNQv')
        price_info = ''.join(price_elements[0].stripped_strings) if price_elements else None
        # 'join' concatenates strings into a single string.
        # 'stripped_strings' retrieves all the strings according to the specified HTML tag

        # extracting the location(since the location is not in the ad key and ad value elements)
        ad_location_elements = t.select('#harita .UD9vJq + div ._3VQ1JB p') # SelectorGadget was used for finding HTML tag
        ad_location = get_texts(ad_location_elements)[0] if ad_location_elements else None

        # extracting the other key-value pairs
        keys = get_texts(t.select('._1bVOdb:nth-child(1)'))# SelectorGadget was used for finding HTML tag
        values = get_texts(t.select('._1bVOdb:nth-child(1) + ._1bVOdb')) # SelectorGadget was used for finding HTML tag

        # constructing the dictionary for key-value pairs
        data = {
            key_ad_number: ad_number_value,
            'price': price_info,
            'location': ad_location
        }

        # adding the other key-value pairs to the dictionary
        data.update(zip(keys, values))

        return data

    except Exception as e:
        print(f"Error processing link {link}: {e}")
        return None

# %%
# extracting the all pages we want:15 pages
all_page_links = ['https://www.emlakjet.com/satilik-konut/antalya/']

links2 = [f"https://www.emlakjet.com/satilik-konut/antalya/{k}/" for k in range(2, 15)]

all_page_links.extend(links2)

all_page_links
# Out:
# ['https://www.emlakjet.com/satilik-konut/antalya/',
#  'https://www.emlakjet.com/satilik-konut/antalya/2/',
#  'https://www.emlakjet.com/satilik-konut/antalya/3/',
#  'https://www.emlakjet.com/satilik-konut/antalya/4/',
#  'https://www.emlakjet.com/satilik-konut/antalya/5/',
#  'https://www.emlakjet.com/satilik-konut/antalya/6/',
#  'https://www.emlakjet.com/satilik-konut/antalya/7/',
#  'https://www.emlakjet.com/satilik-konut/antalya/8/',
#  'https://www.emlakjet.com/satilik-konut/antalya/9/',
#  'https://www.emlakjet.com/satilik-konut/antalya/10/',
#  'https://www.emlakjet.com/satilik-konut/antalya/11/',
#  'https://www.emlakjet.com/satilik-konut/antalya/12/',
#  'https://www.emlakjet.com/satilik-konut/antalya/13/',
#  'https://www.emlakjet.com/satilik-konut/antalya/14/']

# %%
# creating empy list to put the all property links later
all_property_links = []

# iterating through each page 
for page_link in all_page_links:
    # retrieving HTML content 
    response = requests.get(page_link)
    soup = BeautifulSoup(response.text, 'html.parser')

    # finding the all property links within the specified class 
    property_links = [f'https://www.emlakjet.com{x.find("a")["href"]}' for x in soup.select('._3qUI9q') if x.find("a")]

    # adding property links to the empty list(all property links)
    all_property_links.extend(property_links)

# printing all property links 
print(all_property_links)
# Out:
# ['https://www.emlakjet.com/ilan/yeniemek-mah-de-21-genis-ferah-daire-14426602/', 'https://www.emlakjet.com/ilan/fiyat-dustu-kuzeyyaka-mah-de-satilik-arakat-daire-14426397/', 'https://www.emlakjet.com/ilan/belek-yolu-file-market-uzerinde-satilik-31-daire-14426356/', 'https://www.emlakjet.com/ilan/sirinyali-emsalsiz-fiyatta-deniz-manzarali-31-mimar-yapimi-14418580/', 'https://www.emlakjet.com/ilan/teomanpasa-da-satilik-sifir-yuksek-giris-11-daire-14416439/', 'https://www.emlakjet.com/ilan/avsallarin-merkezinde-21-satilik-daire-14411871/', 'https://www.emlakjet.com/ilan/sarilar-camlikta-satilik-uygun-11-14411683/', 'https://www.emlakjet.com/ilan/kizilarik-ta-satilik-muhtesem-proje-de-21-daireler-14411185/', 'https://www.emlakjet.com/ilan/hurma-mahallesinde-luks-site-icerisinde-31-dubleks-14419289/', 'https://www.emlakjet.com/ilan/harika-tasarim-proje-den-satilik-11-ve-21-daireler-14408460/', 'https://www.emlakjet.com/ilan/serik-te-kacirilmayacak-firsata-0-daireler-14408218/', 'https://www.emlakjet.com/ilan/antalya-kepez-santral-mah-suryapi-da-satilik-21-daire-14405363/', 'https://www.emlakjet.com/ilan/antalya-kepez-t-pasa-mh-1170m-giriskepez-beld-300mt-mesafede-14404267/', 'https://www.emlakjet.com/ilan/alanya-demirtas-site-ici-esyali-aktiviteli-satilik-daire-14401541/', 'https://www.emlakjet.com/ilan/avg-gayrimenkul-den-selale-mahallesinde-31-firsat-daire-14400030/', 'https://www.emlakjet.com/ilan/guvensoy-dan-konyaalti-liman-mah-satilik-iskanli-havuzlu-esyali-11-14399514/', 'https://www.emlakjet.com/ilan/acil-satilik-dosemealti-da-luks-ve-genis-51-villa-14399207/', 'https://www.emlakjet.com/ilan/acil-satilik-11daire-14397715/', 'https://www.emlakjet.com/ilan/ultra-luks-daire-14396659/', 'https://www.emlakjet.com/ilan/bu-fiyatta-sifir-21-yok-14396591/', 'https://www.emlakjet.com/ilan/hurma-mahallesinde-luks-site-icerisinde-31-dubleks-14395440/', 'https://www.emlakjet.com/ilan/antalya-kepez-varsak-ayanoglu-mh-31-satilik-villa-14395233/', 'https://www.emlakjet.com/ilan/altintas-ta-site-icerisinde-sifir-satilik-daire-14390160/', 'https://www.emlakjet.com/ilan/cam-ormani-icin-de-satilik-muhtesem-villalar-14388751/', 'https://www.emlakjet.com/ilan/sehrin-merkezin-de-hastaneye-200-metre-konyaalti-plajina-800-metre-muhtesem-proje-14387181/', 'https://www.emlakjet.com/ilan/antalya-kepez-ayanoglu-mh-havuzlu-11-satilik-daire-14386441/', 'https://www.emlakjet.com/ilan/antalya-kepez-kircicegi-cadde-uzeri-31-satilik-daire-14386183/', 'https://www.emlakjet.com/ilan/imam-hatip-lisesine-yakin-cift-balkonlu-genis-31-14376017/', 'https://www.emlakjet.com/ilan/kas-ta-ahsap-kutuk-evler-14374489/', 'https://www.emlakjet.com/ilan/antalya-kepez-de-tramvay-dibi-21-1-katta-100-metre2-net-14373965/', 'https://www.emlakjet.com/ilan/satilik-genis-daire-11-rezidance-14373346/', 'https://www.emlakjet.com/ilan/avsallarda-lux-daire-olive-garden-11-eysali-14373345/', 'https://www.emlakjet.com/ilan/guzeloba-31-havuzlu-site-iceresin-de-satilik-daire-odurum-iznine-uygun-14372902/', 'https://www.emlakjet.com/ilan/kutukcude-21-90m2-bolgenin-en-uygun-dairesi-alan-kazanir-14369671/', 'https://www.emlakjet.com/ilan/teomanpasa-mahallesinde-genis-ebeveyn-banyolu-21-ferah-daire-14369670/', 'https://www.emlakjet.com/ilan/teomanpasa-da-satilik-sifir-yuksek-giris-11-daire-14369656/', 'https://www.emlakjet.com/ilan/sifir-binada-sifir-asansorlu-41-dubleks-daire-14369650/', 'https://www.emlakjet.com/ilan/altintas-ta-satilik-krediye-uygun-11-60-m2-daire-14369648/', 'https://www.emlakjet.com/ilan/muratpasanin-en-uygun-dairesi-31-katta-genis-ferah-14369641/', 'https://www.emlakjet.com/ilan/dudenbasinda-21-yuksek-giris-14369639/', 'https://www.emlakjet.com/ilan/dudenbasinda-21-arac-takasina-acik-daire-14369637/', 'https://www.emlakjet.com/ilan/kepez-gazi-mh-de-11-70m-herseyi-ayri-y-giris-yol-g-d-b-cephe-14369634/', 'https://www.emlakjet.com/ilan/kepez-yeni-mh-11-70m-herseyi-ayri-yerden-2mt-yuksek-giris-14369632/', 'https://www.emlakjet.com/ilan/gundogdunun-en-uygun-katta-genis-31-d ...

# %%
# creating a dataframe to get the information of the all properties
# using map function to use get_one_ship function for all_property_links
data_list = list(map(get_one_ship, all_property_links))
data_list = [item for item in data_list if item is not None]  # filterig out None values
df = pd.DataFrame(data_list)

# printing the DataFrame
df
# Out:
#     İlan Numarası        price                                    location  \
# 0        14426602  2,200,000TL       Antalya - Kepez - Yeni Emek Mahallesi
# 1        14426397  2,200,000TL       Antalya - Kepez - Kuzeyyaka Mahallesi
# 2        14426356  4,250,000TL            Antalya - Serik - Orta Mahallesi
# 3        14418580  8,750,000TL   Antalya - Muratpaşa - Şirinyalı Mahallesi
# 4        14416439  1,600,000TL      Antalya - Kepez - Teomanpaşa Mahallesi
# ..            ...          ...                                         ...
# 415      14423560  1,999,999TL       Antalya - Kepez - Karşıyaka Mahallesi
# 416      14423559  1,725,000TL  Antalya - Muratpaşa - Yüksekalan Mahallesi
# 417      14423554  2,000,000TL           Antalya - Kepez - Güneş Mahallesi
# 418      14423552  1,840,000TL            Antalya - Kepez - Gazi Mahallesi
# 419      14423550  2,490,000TL        Antalya - Kepez - Aydoğmuş Mahallesi
#
#     İlan Güncelleme Tarihi Kategorisi Net Metrekare Oda Sayısı Bulunduğu Kat  \
# 0           20 Aralık 2023    Satılık        100 M2        2+1         3.Kat
# 1           20 Aralık 2023    Satılık         95 M2        2+1         2.Kat
# 2           20 Aralık 2023    Satılık        120 M2        3+1         1.Kat
# 3           20 Aralık 2023    Satılık        150 M2        3+1         7.Kat
# 4           18 Aralık 2023    Satılık         60 M2        1+1  Yüksek Giriş
# ..                     ...        ...           ...        ...           ...
# 415         20 Aralık 2023    Satılık         85 M2        2+1         3.Kat
# 416         20 Aralık 2023    Satılık        100 M2        2+1  Yüksek Giriş
# 417         20 Aralık 2023    Satılık         95 M2        2+1         2.Kat
# 418         20 Aralık 2023    Satılık         90 M2        2+1  Yüksek Giriş
# 419         20 Aralık 2023    Satılık        125 M2        3+1         2.Kat
#
#         Isıtma Tipi     Krediye Uygunluk  ... Görüntülü Gezilebilir mi? Aidat  \
# 0           Klimalı        Krediye Uygun  ...                       NaN   NaN
# 1           Klimalı        Krediye Uygun  ...                       NaN   NaN
# 2    Kombi Doğalgaz        Krediye Uygun  ...                       NaN   NaN
# 3    Kombi Doğalgaz        Krediye Uygun  ...                      Evet   NaN
# 4           Klimalı  Krediye Uygun Değil  ...                       NaN   NaN
# ..              ...                  ...  ...                       ...   ...
# 415         Klimalı        Krediye Uygun  ...                       NaN   NaN
# 416      Isıtma Yok        Krediye Uygun  ...                       NaN   NaN
# 417         Klimalı        Krediye Uygun  ...                       NaN   NaN
# 418      Isıtma Yok        Krediye Uygun  ...                       NaN   NaN
# 419         Klimalı        Krediye Uygun  ...                       NaN   NaN
#
#     Banyo Metrekare Balkon Metrekare WC Metrekare Salon Metrekare  Ada Parsel  \
# 0               NaN              NaN          NaN             NaN  NaN    NaN
# 1               NaN              NaN          NaN             NaN  NaN    NaN
# 2               NaN              NaN          NaN             NaN  NaN    NaN
# 3               NaN              NaN          NaN             NaN  NaN    NaN
# 4               NaN              NaN          NaN             NaN  NaN    NaN
# ..              ...              ...          ...             ...  ...    ...
# 415             NaN              NaN          NaN             NaN  NaN    NaN
# 416             NaN              NaN          NaN             NaN  NaN    NaN
# 417             NaN              NaN          NaN             NaN  NaN    NaN
# 418             NaN              NaN          NaN             NaN  NaN    NaN
# 419             NaN              NaN          NaN             NaN  NaN    NaN
#
#     Pafta Balkon Tipi Fransız Balkon
# 0     NaN                        NaN
# 1     NaN                        NaN
# 2     NaN                        NaN
# 3     NaN                        NaN
# 4     NaN                        NaN
# ..    ...                        ...
# 415   NaN                        NaN
# 416   NaN                        NaN
# 417   NaN                        NaN
# 418   NaN                        NaN
# 419   NaN                        NaN
#
# [420 rows x 43 columns]

# %%
# creating a csv file to save our results
df.to_csv('raw_data.csv', index=False)
